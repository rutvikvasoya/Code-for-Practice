# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
#face detectror backend = ['opencv','ssd','dlib','mtcnn','retinaface']   open cv is default

# %%
#face detection and alignment 

face_detected = DeepFace.detectFace(img_path= 'testing/modi1.jpg')
plt.imshow(face_detected)

# %%
#we can also specify detctor_backend
face_detected = DeepFace.detectFace(img_path= 'testing/modi2.jpg',detector_backend='dlib')
plt.imshow(face_detected)
# cv2.imshow('detedted face',face_detected)
# while(True):
#     k = cv2.waitKey(33)
#     if k == -1:  # if no key was pressed, -1 is returned
#         continue
#     else:
#         break
# cv2.destroyWindow('detedted face')
# Out:
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: /home/ad.rapidops.com/rutvik.vasoya/.deepface/weights/shape_predictor_5_face_landmarks.dat.bz2
# 5.71MB [00:07, 802kB/s]
