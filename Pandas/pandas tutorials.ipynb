# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["rutvik","ketan","rajesh","dj"],
    "marks":[44,6,7,4],
    "city":["rajkot","ahmedabad","jamnagar","surat"]    
}
dict1
# Out:
# {'name': ['rutvik', 'ketan', 'rajesh', 'dj'],
#  'marks': [44, 6, 7, 4],
#  'city': ['rajkot', 'ahmedabad', 'jamnagar', 'surat']}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#      name  marks       city
# 0  rutvik     44     rajkot
# 1   ketan      6  ahmedabad
# 2  rajesh      7   jamnagar
# 3      dj      4      surat

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends_index_false.csv",index=False)

# %%
df.head(2)                                         ##if your data is much bigger and you just want to see some upper rows
# Out:
#      name  marks       city
# 0  rutvik     44     rajkot
# 1   ketan      6  ahmedabad

# %%
df.tail(2)
# Out:
#      name  marks      city
# 2  rajesh      7  jamnagar
# 3      dj      4     surat

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   15.250000
# std    19.207204
# min     4.000000
# 25%     5.500000
# 50%     6.500000
# 75%    16.250000
# max    44.000000

# %%
df2 = pd.read_csv("rutvik.csv")
df2
# Out:
#    Unnamed: 0    name  marks       city
# 0           0  rutvik     44     rajkot
# 1           1   ketan      6  ahmedabad
# 2           2  rajesh      7   jamnagar
# 3           3      dj      4      surat

# %%
df2["name"]
# Out:
# 0    rutvik
# 1     ketan
# 2    rajesh
# 3        dj
# Name: name, dtype: object

# %%
df2["name"][0]
# Out:
# 'rutvik'

# %%
df2["name"][0] = "rutvikbhai"   ##we also can chage the value
# Out:
# C:\Users\Rutvik\AppData\Local\Temp\ipykernel_5172\3057036711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["name"][0] = "rutvikbhai"   ##we also can chage the value

# %%
df2
# Out:
#    Unnamed: 0        name  marks       city
# 0           0  rutvikbhai     44     rajkot
# 1           1       ketan      6  ahmedabad
# 2           2      rajesh      7   jamnagar
# 3           3          dj      4      surat

# %%
df2.index = ["one","two","three","four"]                  ##change the value of index
df2
# Out:
#        Unnamed: 0        name  marks       city
# one             0  rutvikbhai     44     rajkot
# two             1       ketan      6  ahmedabad
# three           2      rajesh      7   jamnagar
# four            3          dj      4      surat

# %%
# Pandas has two type of data structures :
#    a) Series :- it is one dimnensional array with indexes it store a single column or row of data in dataframe
#    b) dataframe :- it is tabular spreadsheet like a structure representing rows each of which contain one or multiple column

# %%
series1 = pd.Series(np.random.rand(34))
series1
# Out:
# 0     0.002718
# 1     0.797871
# 2     0.667043
# 3     0.569005
# 4     0.143811
# 5     0.959466
# 6     0.531602
# 7     0.442391
# 8     0.906859
# 9     0.193169
# 10    0.615483
# 11    0.120398
# 12    0.647256
# 13    0.687324
# 14    0.093393
# 15    0.751044
# 16    0.467156
# 17    0.484436
# 18    0.283397
# 19    0.505341
# 20    0.595589
# 21    0.579891
# 22    0.220571
# 23    0.555759
# 24    0.249732
# 25    0.369322
# 26    0.396008
# 27    0.214918
# 28    0.379085
# 29    0.025306
# 30    0.641175
# 31    0.851028
# 32    0.592185
# 33    0.719558
# dtype: float64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
df3 = pd.DataFrame(np.random.rand(300,5))
df3
# Out:
#             0         1         2         3         4
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.014794  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.describe()
# Out:
#                 0           1           2           3           4
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.516027    0.520166    0.497988    0.505406    0.493016
# std      0.295024    0.290141    0.288392    0.303909    0.299633
# min      0.000793    0.001161    0.000052    0.003867    0.000564
# 25%      0.266793    0.272810    0.235200    0.229630    0.217344
# 50%      0.528502    0.562641    0.487363    0.491771    0.505951
# 75%      0.770752    0.763572    0.753071    0.799430    0.769541
# max      0.998573    0.999038    0.999894    0.999405    0.998247

# %%
df3[0][1]
# Out:
# 0.014793895193278339

# %%
df3[0][1] = 0.344

# %%
df3
# Out:
#             0         1         2         3         4
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df3.head()
# Out:
#           0         1         2         3         4
# 0  0.778604  0.539443  0.724503  0.251387  0.114375
# 1  0.344000  0.582664  0.601348  0.216814  0.569178
# 2  0.002670  0.786167  0.132659  0.127049  0.254240
# 3  0.683385  0.035840  0.618353  0.144315  0.218062
# 4  0.224578  0.832458  0.679854  0.389934  0.595109

# %%
df3.index             ##printing index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
df3.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df3.to_numpy()           ##converting dataframe to numpy
# Out:
# array([[0.778604  , 0.53944316, 0.72450318, 0.25138673, 0.11437545],
#        [0.344     , 0.58266369, 0.60134822, 0.21681439, 0.56917824],
#        [0.00266957, 0.78616739, 0.13265876, 0.12704871, 0.25423986],
#        ...,
#        [0.29123215, 0.93186274, 0.10441339, 0.98051968, 0.7823332 ],
#        [0.46268423, 0.12227614, 0.91717712, 0.85334551, 0.05245254],
#        [0.70649395, 0.62968953, 0.04572191, 0.85608331, 0.24138832]])

# %%
df3.T                 ##row -> column and column -> row
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.778604  0.344000  0.002670  0.683385  0.224578  0.440586  0.293239
# 1  0.539443  0.582664  0.786167  0.035840  0.832458  0.556422  0.683306
# 2  0.724503  0.601348  0.132659  0.618353  0.679854  0.720290  0.594417
# 3  0.251387  0.216814  0.127049  0.144315  0.389934  0.318102  0.801208
# 4  0.114375  0.569178  0.254240  0.218062  0.595109  0.581685  0.924872
#
#         7         8         9    ...       290       291       292       293  \
# 0  0.920653  0.564134  0.367514  ...  0.237115  0.461681  0.195706  0.284672
# 1  0.354997  0.090511  0.085845  ...  0.060568  0.954245  0.741185  0.153924
# 2  0.235919  0.648524  0.001720  ...  0.591587  0.045625  0.198285  0.584962
# 3  0.207955  0.186604  0.098465  ...  0.291704  0.413565  0.004099  0.143243
# 4  0.324254  0.274264  0.212961  ...  0.800816  0.786912  0.803238  0.562419
#
#         294       295       296       297       298       299
# 0  0.126129  0.786262  0.331677  0.291232  0.462684  0.706494
# 1  0.618190  0.332836  0.012173  0.931863  0.122276  0.629690
# 2  0.227927  0.042718  0.439641  0.104413  0.917177  0.045722
# 3  0.818794  0.544449  0.162696  0.980520  0.853346  0.856083
# 4  0.719959  0.897817  0.728012  0.782333  0.052453  0.241388
#
# [5 rows x 300 columns]

# %%
df3.head()
# Out:
#           0         1         2         3         4
# 0  0.778604  0.539443  0.724503  0.251387  0.114375
# 1  0.344000  0.582664  0.601348  0.216814  0.569178
# 2  0.002670  0.786167  0.132659  0.127049  0.254240
# 3  0.683385  0.035840  0.618353  0.144315  0.218062
# 4  0.224578  0.832458  0.679854  0.389934  0.595109

# %%
df3.sort_index()
# Out:
#             0         1         2         3         4
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df3.sort_index(ascending=False)
# Out:
#             0         1         2         3         4
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# ..        ...       ...       ...       ...       ...
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
#
# [300 rows x 5 columns]

# %%
df3.sort_index(ascending=False,axis=1)
# Out:
#             4         3         2         1         0
# 0    0.114375  0.251387  0.724503  0.539443  0.778604
# 1    0.569178  0.216814  0.601348  0.582664  0.344000
# 2    0.254240  0.127049  0.132659  0.786167  0.002670
# 3    0.218062  0.144315  0.618353  0.035840  0.683385
# 4    0.595109  0.389934  0.679854  0.832458  0.224578
# ..        ...       ...       ...       ...       ...
# 295  0.897817  0.544449  0.042718  0.332836  0.786262
# 296  0.728012  0.162696  0.439641  0.012173  0.331677
# 297  0.782333  0.980520  0.104413  0.931863  0.291232
# 298  0.052453  0.853346  0.917177  0.122276  0.462684
# 299  0.241388  0.856083  0.045722  0.629690  0.706494
#
# [300 rows x 5 columns]

# %%
df4 = df3        ##both's memory location is same means if we change in df4 than it will change df3 alos

# %%
df5 = df4.copy()   ##in this memory location is different now we can change df5

# %%
##everytime we need to set any value than we use loc function

# %%
df5
# Out:
#             0         1         2         3         4
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df5.columns = ["A","B","C","D","E"]

# %%
df5
# Out:
#             A         B         C         D         E
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df5.loc[0,1] = 0.333

# %%
df5
# Out:
#             A         B         C         D         E      1
# 0    0.778604  0.539443  0.724503  0.251387  0.114375  0.333
# 1    0.344000  0.582664  0.601348  0.216814  0.569178    NaN
# 2    0.002670  0.786167  0.132659  0.127049  0.254240    NaN
# 3    0.683385  0.035840  0.618353  0.144315  0.218062    NaN
# 4    0.224578  0.832458  0.679854  0.389934  0.595109    NaN
# ..        ...       ...       ...       ...       ...    ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817    NaN
# 296  0.331677  0.012173  0.439641  0.162696  0.728012    NaN
# 297  0.291232  0.931863  0.104413  0.980520  0.782333    NaN
# 298  0.462684  0.122276  0.917177  0.853346  0.052453    NaN
# 299  0.706494  0.629690  0.045722  0.856083  0.241388    NaN
#
# [300 rows x 6 columns]

# %%
df5 = df5.drop(columns=1)

# %%
df5
# Out:
#             A         B         C         D         E
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.344000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df5.loc[1,"A"] = 0.111

# %%
df5.head()
# Out:
#           A         B         C         D         E
# 0  0.778604  0.539443  0.724503  0.251387  0.114375
# 1  0.111000  0.582664  0.601348  0.216814  0.569178
# 2  0.002670  0.786167  0.132659  0.127049  0.254240
# 3  0.683385  0.035840  0.618353  0.144315  0.218062
# 4  0.224578  0.832458  0.679854  0.389934  0.595109

# %%
df5.loc[[1,2],["A","B"]]
# Out:
#          A         B
# 1  0.11100  0.582664
# 2  0.00267  0.786167

# %%
df5.loc[[1,2],:]
# Out:
#          A         B         C         D         E
# 1  0.11100  0.582664  0.601348  0.216814  0.569178
# 2  0.00267  0.786167  0.132659  0.127049  0.254240

# %%
df5.loc[(df5["A"]<0.3) & (df5["C"]>0.22)]
# Out:
#             A         B         C         D         E
# 1    0.111000  0.582664  0.601348  0.216814  0.569178
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# 6    0.293239  0.683306  0.594417  0.801208  0.924872
# 17   0.001736  0.656575  0.804633  0.224091  0.502636
# 24   0.280636  0.446037  0.770363  0.927269  0.846668
# ..        ...       ...       ...       ...       ...
# 282  0.292452  0.831005  0.517484  0.970685  0.115708
# 287  0.160194  0.631474  0.582743  0.907443  0.659341
# 290  0.237115  0.060568  0.591587  0.291704  0.800816
# 293  0.284672  0.153924  0.584962  0.143243  0.562419
# 294  0.126129  0.618190  0.227927  0.818794  0.719959
#
# [72 rows x 5 columns]

# %%
df5
# Out:
#             A         B         C         D         E
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.111000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 5 columns]

# %%
df5.iloc[1,4]
# Out:
# 0.5691782447858615

# %%
df5.iloc[[1,3],[1,2]]
# Out:
#           B         C
# 1  0.582664  0.601348
# 3  0.035840  0.618353

# %%
df5.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.111000  0.582664  0.601348  0.216814  0.569178
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# 5    0.440586  0.556422  0.720290  0.318102  0.581685
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [299 rows x 5 columns]

# %%
df5.drop(["A"],axis=1)
# Out:
#             B         C         D         E
# 0    0.539443  0.724503  0.251387  0.114375
# 1    0.582664  0.601348  0.216814  0.569178
# 2    0.786167  0.132659  0.127049  0.254240
# 3    0.035840  0.618353  0.144315  0.218062
# 4    0.832458  0.679854  0.389934  0.595109
# ..        ...       ...       ...       ...
# 295  0.332836  0.042718  0.544449  0.897817
# 296  0.012173  0.439641  0.162696  0.728012
# 297  0.931863  0.104413  0.980520  0.782333
# 298  0.122276  0.917177  0.853346  0.052453
# 299  0.629690  0.045722  0.856083  0.241388
#
# [300 rows x 4 columns]

# %%
df5.drop([1],inplace=True)              ##changing in orignal database
df5
# Out:
#             A         B         C         D         E
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 2    0.002670  0.786167  0.132659  0.127049  0.254240
# 3    0.683385  0.035840  0.618353  0.144315  0.218062
# 4    0.224578  0.832458  0.679854  0.389934  0.595109
# 5    0.440586  0.556422  0.720290  0.318102  0.581685
# ..        ...       ...       ...       ...       ...
# 295  0.786262  0.332836  0.042718  0.544449  0.897817
# 296  0.331677  0.012173  0.439641  0.162696  0.728012
# 297  0.291232  0.931863  0.104413  0.980520  0.782333
# 298  0.462684  0.122276  0.917177  0.853346  0.052453
# 299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [299 rows x 5 columns]

# %%
df5.reset_index()               ##arrange index  as normal
# Out:
#      index         A         B         C         D         E
# 0        0  0.778604  0.539443  0.724503  0.251387  0.114375
# 1        2  0.002670  0.786167  0.132659  0.127049  0.254240
# 2        3  0.683385  0.035840  0.618353  0.144315  0.218062
# 3        4  0.224578  0.832458  0.679854  0.389934  0.595109
# 4        5  0.440586  0.556422  0.720290  0.318102  0.581685
# ..     ...       ...       ...       ...       ...       ...
# 294    295  0.786262  0.332836  0.042718  0.544449  0.897817
# 295    296  0.331677  0.012173  0.439641  0.162696  0.728012
# 296    297  0.291232  0.931863  0.104413  0.980520  0.782333
# 297    298  0.462684  0.122276  0.917177  0.853346  0.052453
# 298    299  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [299 rows x 6 columns]

# %%
df5.reset_index(drop=True,inplace=True)               ##Drop old index column 
df5
# Out:
#             A         B         C         D         E
# 0    0.778604  0.539443  0.724503  0.251387  0.114375
# 1    0.002670  0.786167  0.132659  0.127049  0.254240
# 2    0.683385  0.035840  0.618353  0.144315  0.218062
# 3    0.224578  0.832458  0.679854  0.389934  0.595109
# 4    0.440586  0.556422  0.720290  0.318102  0.581685
# ..        ...       ...       ...       ...       ...
# 294  0.786262  0.332836  0.042718  0.544449  0.897817
# 295  0.331677  0.012173  0.439641  0.162696  0.728012
# 296  0.291232  0.931863  0.104413  0.980520  0.782333
# 297  0.462684  0.122276  0.917177  0.853346  0.052453
# 298  0.706494  0.629690  0.045722  0.856083  0.241388
#
# [299 rows x 5 columns]

# %%
df5["B"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: B, Length: 299, dtype: bool

# %%
data = {'set_of_numbers': [1,2,3,4,5,np.nan,6,7,np.nan,np.nan,8,9,10,np.nan]}
df6 = pd.DataFrame(data)
df6
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              NaN
# 6              6.0
# 7              7.0
# 8              NaN
# 9              NaN
# 10             8.0
# 11             9.0
# 12            10.0
# 13             NaN

# %%
df6.dropna(how="all")                 ##drop nan value
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 6              6.0
# 7              7.0
# 10             8.0
# 11             9.0
# 12            10.0

# %%
df6
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              NaN
# 6              6.0
# 7              7.0
# 8              NaN
# 9              NaN
# 10             8.0
# 11             9.0
# 12            10.0
# 13             NaN

# %%
df6.drop_duplicates()
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              NaN
# 6              6.0
# 7              7.0
# 10             8.0
# 11             9.0
# 12            10.0

# %%
df6.drop_duplicates(keep="last")
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 6              6.0
# 7              7.0
# 10             8.0
# 11             9.0
# 12            10.0
# 13             NaN

# %%
df6.drop_duplicates(keep=False)
# Out:
#     set_of_numbers
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 6              6.0
# 7              7.0
# 10             8.0
# 11             9.0
# 12            10.0

# %%
df6.shape
# Out:
# (14, 1)

# %%
df6.isnull()
# Out:
#     set_of_numbers
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 5             True
# 6            False
# 7            False
# 8             True
# 9             True
# 10           False
# 11           False
# 12           False
# 13            True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   marks   4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes
